# %%
# Installing required packages
# !pip install pyspark
# !pip install findspark
# Out:
# Requirement already satisfied: pyspark in c:\users\danielpe\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: py4j==0.10.9.3 in c:\users\danielpe\anaconda3\lib\site-packages (from pyspark) (0.10.9.3)
# Requirement already satisfied: findspark in c:\users\danielpe\anaconda3\lib\site-packages (2.0.1)

# %%
import findspark
findspark.init()

# %%
import re
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType

# %%
# Criar o contexto do spark
sc = SparkContext()

# Instancia o criador de sessao do spark
spark = (SparkSession.builder
                     .master("local[*]")
                     .appName("Aceleração PySpark - Capgemini"))

# %%
# Carrega os dados com as configurações necessárias

path_airports = ("../output/airports_qa.parquet")

df_airports_qa = (spark.getOrCreate().read
                  .format("parquet")
                  .option("header", "true")
                  .load(path_airports))

path_planes = ("../output/planes_qa.parquet")

df_planes_qa = (spark.getOrCreate().read
                  .format("parquet")
                  .option("header", "true")
                  .load(path_planes))


path_flights = ("../output/flights_qa.parquet")

df_flights_qa = (spark.getOrCreate().read
                  .format("parquet")
                  .option("header", "true")
                  .load(path_flights))

# %%
# Carrega os dados com as configurações necessárias

path_airports = ("../output/airports_proc.parquet")

df_airports_proc = (spark.getOrCreate().read
                  .format("parquet")
                  .option("header", "true")
                  .load(path_airports))

path_planes = ("../output/planes_proc.parquet")

df_planes_proc = (spark.getOrCreate().read
                  .format("parquet")
                  .option("header", "true")
                  .load(path_planes))


path_flights = ("../output/flights_proc.parquet")

df_flights_proc = (spark.getOrCreate().read
                  .format("parquet")
                  .option("header", "true")
                  .load(path_flights))

# %% [markdown]
# ## Relatórios- Perguntas para qualidade

# %% [markdown]
# #### Pergunta 1

# %%
df_1 = df_airports_qa
df_2 = df_airports_qa

# %%
print('Actual columns:', df_1.columns)


df_1 = (df_1.withColumnRenamed('faa', 'faa_O')
            .withColumnRenamed('qa_faa', 'qa_faa_O')
            .withColumnRenamed('qa_name', 'qa_name_O')
            .withColumnRenamed('qa_lat', 'qa_lat_O')
            .withColumnRenamed('qa_lon', 'qa_lon_O')
            .withColumnRenamed('qa_alt', 'qa_alt_O')
            .withColumnRenamed('qa_tz', 'qa_tz_O')
            .withColumnRenamed('qa_dst', 'qa_dst_O')
                                                                 
              )
print('modified columns:', df_1.columns)

df_1.toPandas()
# Out:
# Actual columns: ['faa', 'qa_faa', 'qa_name', 'qa_lat', 'qa_lon', 'qa_alt', 'qa_tz', 'qa_dst']
# modified columns: ['faa_O', 'qa_faa_O', 'qa_name_O', 'qa_lat_O', 'qa_lon_O', 'qa_alt_O', 'qa_tz_O', 'qa_dst_O']
#      faa_O qa_faa_O qa_name_O qa_lat_O qa_lon_O qa_alt_O qa_tz_O qa_dst_O
# 0      04G        F      None     None     None     None    None     None
# 1      06A        F      None     None     None     None    None     None
# 2      06C        F      None     None     None     None    None     None
# 3      06N        F      None     None     None     None    None     None
# 4      09J        F      None     None     None     None    None     None
# ...    ...      ...       ...      ...      ...      ...     ...      ...
# 1392   ZUN        F      None     None     None     None    None     None
# 1393   ZVE        F      None     None     None     None    None     None
# 1394   ZWI        F      None     None     None     None    None     None
# 1395   ZWU        F      None     None     None     None    None     None
# 1396   ZYP        F      None     None     None     None    None     None
#
# [1397 rows x 8 columns]

# %%
print('Actual columns:', df_2.columns)


df_2 = (df_2.withColumnRenamed('faa', 'faa_D')
            .withColumnRenamed('qa_faa', 'qa_faa_D')
            .withColumnRenamed('qa_name', 'qa_name_D')
            .withColumnRenamed('qa_lat', 'qa_lat_D')
            .withColumnRenamed('qa_lon', 'qa_lon_D')
            .withColumnRenamed('qa_alt', 'qa_alt_D')
            .withColumnRenamed('qa_tz', 'qa_tz_D')
            .withColumnRenamed('qa_dst', 'qa_dst_D')
                                                                 
              )
print('modified columns:', df_2.columns)

df_2.toPandas()
# Out:
# Actual columns: ['faa', 'qa_faa', 'qa_name', 'qa_lat', 'qa_lon', 'qa_alt', 'qa_tz', 'qa_dst']
# modified columns: ['faa_D', 'qa_faa_D', 'qa_name_D', 'qa_lat_D', 'qa_lon_D', 'qa_alt_D', 'qa_tz_D', 'qa_dst_D']
#      faa_D qa_faa_D qa_name_D qa_lat_D qa_lon_D qa_alt_D qa_tz_D qa_dst_D
# 0      04G        F      None     None     None     None    None     None
# 1      06A        F      None     None     None     None    None     None
# 2      06C        F      None     None     None     None    None     None
# 3      06N        F      None     None     None     None    None     None
# 4      09J        F      None     None     None     None    None     None
# ...    ...      ...       ...      ...      ...      ...     ...      ...
# 1392   ZUN        F      None     None     None     None    None     None
# 1393   ZVE        F      None     None     None     None    None     None
# 1394   ZWI        F      None     None     None     None    None     None
# 1395   ZWU        F      None     None     None     None    None     None
# 1396   ZYP        F      None     None     None     None    None     None
#
# [1397 rows x 8 columns]

# %%
print('Actual columns:', df_planes_qa.columns)


df_planes_qa = (df_planes_qa.withColumnRenamed('tailnum', 'tailnum_P')
                            .withColumnRenamed('qa_tailnum', 'qa_tailnum_P')
                                                                 
              )
print('modified columns:', df_planes_qa.columns)

df_planes_qa.toPandas()
# Out:
# Actual columns: ['tailnum', 'qa_tailnum', 'qa_year', 'qa_type', 'qa_manufacturer', 'qa_model', 'qa_engines', 'qa_seats', 'qa_speed', 'qa_engine']
# modified columns: ['tailnum_P', 'qa_tailnum_P', 'qa_year', 'qa_type', 'qa_manufacturer', 'qa_model', 'qa_engines', 'qa_seats', 'qa_speed', 'qa_engine']
#      tailnum_P qa_tailnum_P qa_year qa_type qa_manufacturer qa_model  \
# 0       N102UW         None    None    None               C     None
# 1       N103US         None    None    None               C     None
# 2       N104UW         None    None    None               C     None
# 3       N105UW         None    None    None               C     None
# 4       N107US         None    None    None               C     None
# ...        ...          ...     ...     ...             ...      ...
# 2623    N983SW         None    None    None               C     None
# 2624    N984CA         None    None    None            None     None
# 2625    N986CA         None       M    None            None     None
# 2626    N986SW         None    None    None               C     None
# 2627    N988CA         None    None    None            None     None
#
#      qa_engines qa_seats qa_speed qa_engine
# 0          None     None        M      None
# 1          None     None        M      None
# 2          None     None        M      None
# 3          None     None        M      None
# 4          None     None        M      None
# ...         ...      ...      ...       ...
# 2623       None     None        M      None
# 2624       None     None        M      None
# 2625       None     None        M      None
# 2626       None     None        M      None
# 2627       None     None        M      None
#
# [2628 rows x 10 columns]

# %%
df = (df_flights_qa.join(df_1,
                  (df_flights_qa.origin == df_1.faa_O)
                        ,"left")
)

# %%
df.printSchema()
# Out:
# root
#  |-- tailnum: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- dest: string (nullable = true)
#  |-- qa_year_month_day: string (nullable = true)
#  |-- qa_hour_minute: string (nullable = true)
#  |-- qa_dep_arr_time: string (nullable = true)
#  |-- qa_dep_arr_delay: string (nullable = true)
#  |-- qa_carrier: string (nullable = true)
#  |-- qa_tailnum: string (nullable = true)
#  |-- qa_flight: string (nullable = true)
#  |-- qa_origin_dest: string (nullable = true)
#  |-- qa_air_time: string (nullable = true)
#  |-- qa_distance: string (nullable = true)
#  |-- qa_distance_airtime: string (nullable = true)
#  |-- faa_O: string (nullable = true)
#  |-- qa_faa_O: string (nullable = true)
#  |-- qa_name_O: string (nullable = true)
#  |-- qa_lat_O: string (nullable = true)
#  |-- qa_lon_O: string (nullable = true)
#  |-- qa_alt_O: string (nullable = true)
#  |-- qa_tz_O: string (nullable = true)
#  |-- qa_dst_O: string (nullable = true)

# %%
df = (df.join(df_2,
                  (df.origin == df_2.faa_D)
                        ,"left")
)

# %%
df.printSchema()
# Out:
# root
#  |-- tailnum: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- dest: string (nullable = true)
#  |-- qa_year_month_day: string (nullable = true)
#  |-- qa_hour_minute: string (nullable = true)
#  |-- qa_dep_arr_time: string (nullable = true)
#  |-- qa_dep_arr_delay: string (nullable = true)
#  |-- qa_carrier: string (nullable = true)
#  |-- qa_tailnum: string (nullable = true)
#  |-- qa_flight: string (nullable = true)
#  |-- qa_origin_dest: string (nullable = true)
#  |-- qa_air_time: string (nullable = true)
#  |-- qa_distance: string (nullable = true)
#  |-- qa_distance_airtime: string (nullable = true)
#  |-- faa_O: string (nullable = true)
#  |-- qa_faa_O: string (nullable = true)
#  |-- qa_name_O: string (nullable = true)
#  |-- qa_lat_O: string (nullable = true)
#  |-- qa_lon_O: string (nullable = true)
#  |-- qa_alt_O: string (nullable = true)
#  |-- qa_tz_O: string (nullable = true)
#  |-- qa_dst_O: string (nullable = true)
#  |-- faa_D: string (nullable = true)
#  |-- qa_faa_D: string (nullable = true)
#  |-- qa_name_D: string (nullable = true)
#  |-- qa_lat_D: string (nullable = true)
#  |-- qa_lon_D: string (nullable = true)
#  |-- qa_alt_D: string (nullable = true)
#  |-- qa_tz_D: string (nullable = true)
#  |-- qa_dst_D: string (nullable = true)

# %%
df = (df.join(df_planes_qa,
                  (df.tailnum == df_planes_qa.tailnum_P)
                        ,"left")
)

# %%
df.printSchema()
# Out:
# root
#  |-- tailnum: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- dest: string (nullable = true)
#  |-- qa_year_month_day: string (nullable = true)
#  |-- qa_hour_minute: string (nullable = true)
#  |-- qa_dep_arr_time: string (nullable = true)
#  |-- qa_dep_arr_delay: string (nullable = true)
#  |-- qa_carrier: string (nullable = true)
#  |-- qa_tailnum: string (nullable = true)
#  |-- qa_flight: string (nullable = true)
#  |-- qa_origin_dest: string (nullable = true)
#  |-- qa_air_time: string (nullable = true)
#  |-- qa_distance: string (nullable = true)
#  |-- qa_distance_airtime: string (nullable = true)
#  |-- faa_O: string (nullable = true)
#  |-- qa_faa_O: string (nullable = true)
#  |-- qa_name_O: string (nullable = true)
#  |-- qa_lat_O: string (nullable = true)
#  |-- qa_lon_O: string (nullable = true)
#  |-- qa_alt_O: string (nullable = true)
#  |-- qa_tz_O: string (nullable = true)
#  |-- qa_dst_O: string (nullable = true)
#  |-- faa_D: string (nullable = true)
#  |-- qa_faa_D: string (nullable = true)
#  |-- qa_name_D: string (nullable = true)
#  |-- qa_lat_D: string (nullable = true)
#  |-- qa_lon_D: string (nullable = true)
#  |-- qa_alt_D: string (nullable = true)
#  |-- qa_tz_D: string (nullable = true)
#  |-- qa_dst_D: string (nullable = true)
#  |-- tailnum_P: string (nullable = true)
#  |-- qa_tailnum_P: string (nullable = true)
#  |-- qa_year: string (nullable = true)
#  |-- qa_type: string (nullable = true)
#  |-- qa_manufacturer: string (nullable = true)
#  |-- qa_model: string (nullable = true)
#  |-- qa_engines: string (nullable = true)
#  |-- qa_seats: string (nullable = true)
#  |-- qa_speed: string (nullable = true)
#  |-- qa_engine: string (nullable = true)

# %%
len(df.columns)
# Out:
# 40

# %% [markdown]
# #### Pergunta 2

# %%
df_qa = df.select(df.colRegex("`^qa_.*`"))

for c in df_qa.columns:
    df_qa.filter(F.col(c).isNotNull()).groupBy(F.substring(c, 1, 1).alias(c)).count().show()
# Out:
# +-----------------+-----+
# |qa_year_month_day|count|
# +-----------------+-----+
# +-----------------+-----+
#
# +--------------+-----+
# |qa_hour_minute|count|
# +--------------+-----+
# |             M|   48|
# +--------------+-----+
#
# +---------------+-----+
# |qa_dep_arr_time|count|
# +---------------+-----+
# |              F|  241|
# |              M|   55|
# +---------------+-----+
#
# +----------------+-----+
# |qa_dep_arr_delay|count|
# +----------------+-----+
# |               M|   75|
# +----------------+-----+
#
# +----------+-----+
# |qa_carrier|count|
# +----------+-----+
# +----------+-----+
#
# +----------+-----+
# |qa_tailnum|count|
# +----------+-----+
# |         F|  989|
# |         M|   14|
# +----------+-----+
#
# +---------+-----+
# |qa_flight|count|
# +---------+-----+
# |        F| 6158|
# +---------+-----+
#
# +--------------+-----+
# |qa_origin_dest|count|
# +--------------+-----+
# +--------------+-----+
#
# +-----------+-----+
# |qa_air_time|count|
# +-----------+-----+
# |          M|   75|
# +-----------+-----+
#
# +-----------+-----+
# |qa_distance|count|
# +-----------+-----+
# +-----------+-----+
#
# +-------------------+-----+
# |qa_distance_airtime|count|
# +-------------------+-----+
# |                  T| 9925|
# |                  M|   75|
# +-------------------+-----+
#
# +--------+-----+
# |qa_faa_O|count|
# +--------+-----+
# |       F|10000|
# +--------+-----+
#
# +---------+-----+
# |qa_name_O|count|
# +---------+-----+
# +---------+-----+
#
# +--------+-----+
# |qa_lat_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_lon_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_alt_O|count|
# +--------+-----+
# +--------+-----+
#
# +-------+-----+
# |qa_tz_O|count|
# +-------+-----+
# +-------+-----+
#
# +--------+-----+
# |qa_dst_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_faa_D|count|
# +--------+-----+
# |       F|10000|
# +--------+-----+
#
# +---------+-----+
# |qa_name_D|count|
# +---------+-----+
# +---------+-----+
#
# +--------+-----+
# |qa_lat_D|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_lon_D|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_alt_D|count|
# +--------+-----+
# +--------+-----+
#
# +-------+-----+
# |qa_tz_D|count|
# +-------+-----+
# +-------+-----+
#
# +--------+-----+
# |qa_dst_D|count|
# +--------+-----+
# +--------+-----+
#
# +------------+-----+
# |qa_tailnum_P|count|
# +------------+-----+
# |           F|  552|
# +------------+-----+
#
# +-------+-----+
# |qa_year|count|
# +-------+-----+
# |      M|   94|
# |      I|    8|
# +-------+-----+
#
# +-------+-----+
# |qa_type|count|
# +-------+-----+
# +-------+-----+
#
# +---------------+-----+
# |qa_manufacturer|count|
# +---------------+-----+
# |              C| 1644|
# +---------------+-----+
#
# +--------+-----+
# |qa_model|count|
# +--------+-----+
# |       F|    9|
# +--------+-----+
#
# +----------+-----+
# |qa_engines|count|
# +----------+-----+
# +----------+-----+
#
# +--------+-----+
# |qa_seats|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_speed|count|
# +--------+-----+
# |       M| 9443|
# +--------+-----+
#
# +---------+-----+
# |qa_engine|count|
# +---------+-----+
# |        C|    7|
# +---------+-----+

# %% [markdown]
# #### Pergunta 3

# %%
df_qa_M = df.select(df.colRegex("`^qa_.*`"))

for c in df_qa.columns:
    df_qa.filter(F.col(c) == 'M').groupBy(F.substring(c, 1, 1).alias(c)).count().show()
# Out:
# +-----------------+-----+
# |qa_year_month_day|count|
# +-----------------+-----+
# +-----------------+-----+
#
# +--------------+-----+
# |qa_hour_minute|count|
# +--------------+-----+
# +--------------+-----+
#
# +---------------+-----+
# |qa_dep_arr_time|count|
# +---------------+-----+
# +---------------+-----+
#
# +----------------+-----+
# |qa_dep_arr_delay|count|
# +----------------+-----+
# +----------------+-----+
#
# +----------+-----+
# |qa_carrier|count|
# +----------+-----+
# +----------+-----+
#
# +----------+-----+
# |qa_tailnum|count|
# +----------+-----+
# |         M|   14|
# +----------+-----+
#
# +---------+-----+
# |qa_flight|count|
# +---------+-----+
# +---------+-----+
#
# +--------------+-----+
# |qa_origin_dest|count|
# +--------------+-----+
# +--------------+-----+
#
# +-----------+-----+
# |qa_air_time|count|
# +-----------+-----+
# |          M|   75|
# +-----------+-----+
#
# +-----------+-----+
# |qa_distance|count|
# +-----------+-----+
# +-----------+-----+
#
# +-------------------+-----+
# |qa_distance_airtime|count|
# +-------------------+-----+
# |                  M|   75|
# +-------------------+-----+
#
# +--------+-----+
# |qa_faa_O|count|
# +--------+-----+
# +--------+-----+
#
# +---------+-----+
# |qa_name_O|count|
# +---------+-----+
# +---------+-----+
#
# +--------+-----+
# |qa_lat_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_lon_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_alt_O|count|
# +--------+-----+
# +--------+-----+
#
# +-------+-----+
# |qa_tz_O|count|
# +-------+-----+
# +-------+-----+
#
# +--------+-----+
# |qa_dst_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_faa_D|count|
# +--------+-----+
# +--------+-----+
#
# +---------+-----+
# |qa_name_D|count|
# +---------+-----+
# +---------+-----+
#
# +--------+-----+
# |qa_lat_D|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_lon_D|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_alt_D|count|
# +--------+-----+
# +--------+-----+
#
# +-------+-----+
# |qa_tz_D|count|
# +-------+-----+
# +-------+-----+
#
# +--------+-----+
# |qa_dst_D|count|
# +--------+-----+
# +--------+-----+
#
# +------------+-----+
# |qa_tailnum_P|count|
# +------------+-----+
# +------------+-----+
#
# +-------+-----+
# |qa_year|count|
# +-------+-----+
# |      M|   94|
# +-------+-----+
#
# +-------+-----+
# |qa_type|count|
# +-------+-----+
# +-------+-----+
#
# +---------------+-----+
# |qa_manufacturer|count|
# +---------------+-----+
# +---------------+-----+
#
# +--------+-----+
# |qa_model|count|
# +--------+-----+
# +--------+-----+
#
# +----------+-----+
# |qa_engines|count|
# +----------+-----+
# +----------+-----+
#
# +--------+-----+
# |qa_seats|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_speed|count|
# +--------+-----+
# |       M| 9443|
# +--------+-----+
#
# +---------+-----+
# |qa_engine|count|
# +---------+-----+
# +---------+-----+

# %% [markdown]
# #### Pergunta 4

# %%
df_qa_F = df.select(df.colRegex("`^qa_.*`"))

for c in df_qa.columns:
    df_qa.filter(F.col(c) == 'F').groupBy(F.substring(c, 1, 1).alias(c)).count().show()
# Out:
# +-----------------+-----+
# |qa_year_month_day|count|
# +-----------------+-----+
# +-----------------+-----+
#
# +--------------+-----+
# |qa_hour_minute|count|
# +--------------+-----+
# +--------------+-----+
#
# +---------------+-----+
# |qa_dep_arr_time|count|
# +---------------+-----+
# +---------------+-----+
#
# +----------------+-----+
# |qa_dep_arr_delay|count|
# +----------------+-----+
# +----------------+-----+
#
# +----------+-----+
# |qa_carrier|count|
# +----------+-----+
# +----------+-----+
#
# +----------+-----+
# |qa_tailnum|count|
# +----------+-----+
# |         F|  987|
# +----------+-----+
#
# +---------+-----+
# |qa_flight|count|
# +---------+-----+
# |        F| 6158|
# +---------+-----+
#
# +--------------+-----+
# |qa_origin_dest|count|
# +--------------+-----+
# +--------------+-----+
#
# +-----------+-----+
# |qa_air_time|count|
# +-----------+-----+
# +-----------+-----+
#
# +-----------+-----+
# |qa_distance|count|
# +-----------+-----+
# +-----------+-----+
#
# +-------------------+-----+
# |qa_distance_airtime|count|
# +-------------------+-----+
# +-------------------+-----+
#
# +--------+-----+
# |qa_faa_O|count|
# +--------+-----+
# |       F|10000|
# +--------+-----+
#
# +---------+-----+
# |qa_name_O|count|
# +---------+-----+
# +---------+-----+
#
# +--------+-----+
# |qa_lat_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_lon_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_alt_O|count|
# +--------+-----+
# +--------+-----+
#
# +-------+-----+
# |qa_tz_O|count|
# +-------+-----+
# +-------+-----+
#
# +--------+-----+
# |qa_dst_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_faa_D|count|
# +--------+-----+
# |       F|10000|
# +--------+-----+
#
# +---------+-----+
# |qa_name_D|count|
# +---------+-----+
# +---------+-----+
#
# +--------+-----+
# |qa_lat_D|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_lon_D|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_alt_D|count|
# +--------+-----+
# +--------+-----+
#
# +-------+-----+
# |qa_tz_D|count|
# +-------+-----+
# +-------+-----+
#
# +--------+-----+
# |qa_dst_D|count|
# +--------+-----+
# +--------+-----+
#
# +------------+-----+
# |qa_tailnum_P|count|
# +------------+-----+
# |           F|  552|
# +------------+-----+
#
# +-------+-----+
# |qa_year|count|
# +-------+-----+
# +-------+-----+
#
# +-------+-----+
# |qa_type|count|
# +-------+-----+
# +-------+-----+
#
# +---------------+-----+
# |qa_manufacturer|count|
# +---------------+-----+
# +---------------+-----+
#
# +--------+-----+
# |qa_model|count|
# +--------+-----+
# |       F|    9|
# +--------+-----+
#
# +----------+-----+
# |qa_engines|count|
# +----------+-----+
# +----------+-----+
#
# +--------+-----+
# |qa_seats|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_speed|count|
# +--------+-----+
# +--------+-----+
#
# +---------+-----+
# |qa_engine|count|
# +---------+-----+
# +---------+-----+

# %% [markdown]
# #### Pergunta 5

# %%
df_qa_M = df.select(df.colRegex("`^qa_.*`"))

for c in df_qa.columns:
    df_qa.filter(F.col(c) == 'I').groupBy(F.substring(c, 1, 1).alias(c)).count().show()
# Out:
# +-----------------+-----+
# |qa_year_month_day|count|
# +-----------------+-----+
# +-----------------+-----+
#
# +--------------+-----+
# |qa_hour_minute|count|
# +--------------+-----+
# +--------------+-----+
#
# +---------------+-----+
# |qa_dep_arr_time|count|
# +---------------+-----+
# +---------------+-----+
#
# +----------------+-----+
# |qa_dep_arr_delay|count|
# +----------------+-----+
# +----------------+-----+
#
# +----------+-----+
# |qa_carrier|count|
# +----------+-----+
# +----------+-----+
#
# +----------+-----+
# |qa_tailnum|count|
# +----------+-----+
# +----------+-----+
#
# +---------+-----+
# |qa_flight|count|
# +---------+-----+
# +---------+-----+
#
# +--------------+-----+
# |qa_origin_dest|count|
# +--------------+-----+
# +--------------+-----+
#
# +-----------+-----+
# |qa_air_time|count|
# +-----------+-----+
# +-----------+-----+
#
# +-----------+-----+
# |qa_distance|count|
# +-----------+-----+
# +-----------+-----+
#
# +-------------------+-----+
# |qa_distance_airtime|count|
# +-------------------+-----+
# +-------------------+-----+
#
# +--------+-----+
# |qa_faa_O|count|
# +--------+-----+
# +--------+-----+
#
# +---------+-----+
# |qa_name_O|count|
# +---------+-----+
# +---------+-----+
#
# +--------+-----+
# |qa_lat_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_lon_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_alt_O|count|
# +--------+-----+
# +--------+-----+
#
# +-------+-----+
# |qa_tz_O|count|
# +-------+-----+
# +-------+-----+
#
# +--------+-----+
# |qa_dst_O|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_faa_D|count|
# +--------+-----+
# +--------+-----+
#
# +---------+-----+
# |qa_name_D|count|
# +---------+-----+
# +---------+-----+
#
# +--------+-----+
# |qa_lat_D|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_lon_D|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_alt_D|count|
# +--------+-----+
# +--------+-----+
#
# +-------+-----+
# |qa_tz_D|count|
# +-------+-----+
# +-------+-----+
#
# +--------+-----+
# |qa_dst_D|count|
# +--------+-----+
# +--------+-----+
#
# +------------+-----+
# |qa_tailnum_P|count|
# +------------+-----+
# +------------+-----+
#
# +-------+-----+
# |qa_year|count|
# +-------+-----+
# |      I|    8|
# +-------+-----+
#
# +-------+-----+
# |qa_type|count|
# +-------+-----+
# +-------+-----+
#
# +---------------+-----+
# |qa_manufacturer|count|
# +---------------+-----+
# +---------------+-----+
#
# +--------+-----+
# |qa_model|count|
# +--------+-----+
# +--------+-----+
#
# +----------+-----+
# |qa_engines|count|
# +----------+-----+
# +----------+-----+
#
# +--------+-----+
# |qa_seats|count|
# +--------+-----+
# +--------+-----+
#
# +--------+-----+
# |qa_speed|count|
# +--------+-----+
# +--------+-----+
#
# +---------+-----+
# |qa_engine|count|
# +---------+-----+
# +---------+-----+

# %% [markdown]
# ## Relatórios - Perguntas para negócio

# %% [markdown]
# #### Pergunta 1

# %%
df_airports_proc.toPandas()
# Out:
#       faa                           name        lat         lon   alt   tz  \
# 0     04G              Lansdowne Airport  41.130474  -80.619583  1044 -5.0
# 1     06A  Moton Field Municipal Airport  32.460571  -85.680031   264 -5.0
# 2     06C            Schaumburg Regional  41.989342  -88.101242   801 -6.0
# 3     06N                Randall Airport  41.431911  -74.391563   523 -5.0
# 4     09J          Jekyll Island Airport  31.074472  -81.427780    11 -4.0
# ...   ...                            ...        ...         ...   ...  ...
# 1392  ZUN                     Black Rock  35.083229 -108.791779  6454 -7.0
# 1393  ZVE         New Haven Rail Station  41.298668  -72.925995     7 -5.0
# 1394  ZWI      Wilmington Amtrak Station  39.736668  -75.551666     0 -5.0
# 1395  ZWU       Washington Union Station  38.897461  -77.006432    76 -5.0
# 1396  ZYP                   Penn Station  40.750500  -73.993500    35 -5.0
#
#      dst         region type  military administration
# 0      A  MAINLAND-EAST   AP     False            NaN
# 1      A  MAINLAND-EAST   AP     False              M
# 2      A  MAINLAND-EAST  NaN     False              R
# 3      A  MAINLAND-EAST   AP     False            NaN
# 4      A  MAINLAND-EAST   AP     False            NaN
# ...   ..            ...  ...       ...            ...
# 1392   A  MAINLAND-WEST  NaN     False            NaN
# 1393   A  MAINLAND-EAST   AS     False            NaN
# 1394   A  MAINLAND-EAST   AS     False            NaN
# 1395   A  MAINLAND-EAST   AS     False            NaN
# 1396   A  MAINLAND-EAST   AS     False            NaN
#
# [1397 rows x 11 columns]

# %%
df_airports_proc.select(df_airports_proc.region).groupBy(df_airports_proc.region).count().toPandas()
# Out:
#           region  count
# 0         ALASKA    261
# 1       OFFSHORE      4
# 2  MAINLAND-EAST    696
# 3  MAINLAND-WEST    436

# %%
df_planes_proc.toPandas()
# Out:
#      tailnum    year       type manufacturer        model  engines  seats  \
# 0     N102UW  1998.0  MULTI_ENG       AIRBUS     A320-214        2    182
# 1     N103US  1999.0  MULTI_ENG       AIRBUS     A320-214        2    182
# 2     N104UW  1999.0  MULTI_ENG       AIRBUS     A320-214        2    182
# 3     N105UW  1999.0  MULTI_ENG       AIRBUS     A320-214        2    182
# 4     N107US  1999.0  MULTI_ENG       AIRBUS     A320-214        2    182
# ...      ...     ...        ...          ...          ...      ...    ...
# 2623  N983SW  2004.0  MULTI_ENG   BOMBARDIER  CL-600-2B19        2     55
# 2624  N984CA  1997.0  MULTI_ENG     CANADAIR  CL-600-2B19        2     55
# 2625  N986CA  1995.0  MULTI_ENG     CANADAIR  CL-600-2B19        2     55
# 2626  N986SW  2004.0  MULTI_ENG   BOMBARDIER  CL-600-2B19        2     55
# 2627  N988CA  1997.0  MULTI_ENG     CANADAIR  CL-600-2B19        2     55
#
#       speed     engine tailchar   age engine_type
# 0         0  Turbo-fan       UW  24.0         FAN
# 1         0  Turbo-fan       US  23.0         FAN
# 2         0  Turbo-fan       UW  23.0         FAN
# 3         0  Turbo-fan       UW  23.0         FAN
# 4         0  Turbo-fan       US  23.0         FAN
# ...     ...        ...      ...   ...         ...
# 2623      0  Turbo-fan       SW  18.0         FAN
# 2624      0  Turbo-fan       CA  25.0         FAN
# 2625      0  Turbo-fan       CA  27.0         FAN
# 2626      0  Turbo-fan       SW  18.0         FAN
# 2627      0  Turbo-fan       CA  25.0         FAN
#
# [2628 rows x 12 columns]

# %%
df_flights_proc.toPandas()
# Out:
#      dep_time arr_time  dep_delay  arr_delay carrier tailnum flight origin  \
# 0         658      935         -7         -5      VX  N846VA   1780    SEA
# 1        1040     1505          5          5      AS  N559AS    851    SEA
# 2        1443     1652         -2          2      VX  N847VA    755    SEA
# 3        1705     1839         45         34      WN  N360SW    344    PDX
# 4         754     1015         -1          1      AS  N612AS    522    SEA
# ...       ...      ...        ...        ...     ...     ...    ...    ...
# 9995     1806     2104         -4         -6      OO  N225AG   3458    SEA
# 9996     2336      452         11        -13      AA  N3LEAA   1230    SEA
# 9997      904     1042         -1         -5      AS  N523AS    360    SEA
# 9998     1441     1820         26         10      WN  N8647A   2857    SEA
# 9999     1702     1950         -3        -10      DL  N583NW   2237    SEA
#
#      dest  air_time  distance        dep_datetime  air_time_projected  \
# 0     LAX       132       954 2014-12-08 06:58:00                 115
# 1     HNL       360      2677 2014-01-22 10:40:00                 287
# 2     SFO       111       679 2014-03-09 14:43:00                  87
# 3     SJC        83       569 2014-04-09 17:05:00                  76
# 4     BUR       127       937 2014-03-09 07:54:00                 113
# ...   ...       ...       ...                 ...                 ...
# 9995  SLC        89       689 2014-06-23 18:06:00                  88
# 9996  DFW       178      1660 2014-08-31 23:36:00                 186
# 9997  SMF        81       605 2014-08-08 09:04:00                  80
# 9998  ABQ       133      1180 2014-08-29 14:41:00                 138
# 9999  HNL       332      2677 2014-07-13 17:02:00                 287
#
#       air_time_expected haul_duration dep_season dep_delay_category
# 0                   126    SHORT-HAUL       FALL        ANTECIPATED
# 1                   343   MEDIUM-HAUL     WINTER              MINOR
# 2                   101    SHORT-HAUL     WINTER        ANTECIPATED
# 3                    85    SHORT-HAUL     SPRING              MINOR
# 4                   122    SHORT-HAUL     WINTER        ANTECIPATED
# ...                 ...           ...        ...                ...
# 9995                 88    SHORT-HAUL     SUMMER        ANTECIPATED
# 9996                195    SHORT-HAUL     SUMMER              MINOR
# 9997                 82    SHORT-HAUL     SUMMER        ANTECIPATED
# 9998                142    SHORT-HAUL     SUMMER              MINOR
# 9999                343   MEDIUM-HAUL     SUMMER        ANTECIPATED
#
# [10000 rows x 17 columns]

# %%
df_flights_proc.printSchema()
# Out:
# root
#  |-- dep_time: string (nullable = true)
#  |-- arr_time: string (nullable = true)
#  |-- dep_delay: integer (nullable = true)
#  |-- arr_delay: integer (nullable = true)
#  |-- carrier: string (nullable = true)
#  |-- tailnum: string (nullable = true)
#  |-- flight: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- dest: string (nullable = true)
#  |-- air_time: integer (nullable = true)
#  |-- distance: integer (nullable = true)
#  |-- dep_datetime: timestamp (nullable = true)
#  |-- air_time_projected: integer (nullable = true)
#  |-- air_time_expected: integer (nullable = true)
#  |-- haul_duration: string (nullable = true)
#  |-- dep_season: string (nullable = true)
#  |-- dep_delay_category: string (nullable = true)

# %%
df_airports_proc.printSchema()
# Out:
# root
#  |-- faa: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- lat: float (nullable = true)
#  |-- lon: float (nullable = true)
#  |-- alt: integer (nullable = true)
#  |-- tz: float (nullable = true)
#  |-- dst: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- military: boolean (nullable = true)
#  |-- administration: string (nullable = true)

# %%
df_planes_proc.printSchema()
# Out:
# root
#  |-- tailnum: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- type: string (nullable = true)
#  |-- manufacturer: string (nullable = true)
#  |-- model: string (nullable = true)
#  |-- engines: integer (nullable = true)
#  |-- seats: integer (nullable = true)
#  |-- speed: integer (nullable = true)
#  |-- engine: string (nullable = true)
#  |-- tailchar: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- engine_type: string (nullable = true)

# %%
df_1 = df_airports_proc
df_2 = df_airports_proc

# %%
print('Actual columns:', df_1.columns)


df_1 = (df_1.withColumnRenamed('faa', 'faa_O')
            .withColumnRenamed('name', 'name_O')
            .withColumnRenamed('lat', 'lat_O')
            .withColumnRenamed('lon', 'lon_O')
            .withColumnRenamed('alt', 'alt_O')
            .withColumnRenamed('tz', 'tz_O')
            .withColumnRenamed('dst', 'dst_O')
            .withColumnRenamed('region', 'region_O')
            .withColumnRenamed('type', 'type_O')
            .withColumnRenamed('military', 'military_O')
            .withColumnRenamed('administration', 'administration_O')
                                                                 
              )
print('modified columns:', df_1.columns)

df_1.toPandas()
# Out:
# Actual columns: ['faa', 'name', 'lat', 'lon', 'alt', 'tz', 'dst', 'region', 'type', 'military', 'administration']
# modified columns: ['faa_O', 'name_O', 'lat_O', 'lon_O', 'alt_O', 'tz_O', 'dst_O', 'region_O', 'type_O', 'military_O', 'administration_O']
#      faa_O                         name_O      lat_O       lon_O  alt_O  tz_O  \
# 0      04G              Lansdowne Airport  41.130474  -80.619583   1044  -5.0
# 1      06A  Moton Field Municipal Airport  32.460571  -85.680031    264  -5.0
# 2      06C            Schaumburg Regional  41.989342  -88.101242    801  -6.0
# 3      06N                Randall Airport  41.431911  -74.391563    523  -5.0
# 4      09J          Jekyll Island Airport  31.074472  -81.427780     11  -4.0
# ...    ...                            ...        ...         ...    ...   ...
# 1392   ZUN                     Black Rock  35.083229 -108.791779   6454  -7.0
# 1393   ZVE         New Haven Rail Station  41.298668  -72.925995      7  -5.0
# 1394   ZWI      Wilmington Amtrak Station  39.736668  -75.551666      0  -5.0
# 1395   ZWU       Washington Union Station  38.897461  -77.006432     76  -5.0
# 1396   ZYP                   Penn Station  40.750500  -73.993500     35  -5.0
#
#      dst_O       region_O type_O  military_O administration_O
# 0        A  MAINLAND-EAST     AP       False              NaN
# 1        A  MAINLAND-EAST     AP       False                M
# 2        A  MAINLAND-EAST    NaN       False                R
# 3        A  MAINLAND-EAST     AP       False              NaN
# 4        A  MAINLAND-EAST     AP       False              NaN
# ...    ...            ...    ...         ...              ...
# 1392     A  MAINLAND-WEST    NaN       False              NaN
# 1393     A  MAINLAND-EAST     AS       False              NaN
# 1394     A  MAINLAND-EAST     AS       False              NaN
# 1395     A  MAINLAND-EAST     AS       False              NaN
# 1396     A  MAINLAND-EAST     AS       False              NaN
#
# [1397 rows x 11 columns]

# %%
print('Actual columns:', df_2.columns)


df_2 = (df_2.withColumnRenamed('faa', 'faa_D')
            .withColumnRenamed('name', 'name_D')
            .withColumnRenamed('lat', 'lat_D')
            .withColumnRenamed('lon', 'lon_D')
            .withColumnRenamed('alt', 'alt_D')
            .withColumnRenamed('tz', 'tz_D')
            .withColumnRenamed('dst', 'dst_D')
            .withColumnRenamed('region', 'region_D')
            .withColumnRenamed('type', 'type_D')
            .withColumnRenamed('military', 'military_D')
            .withColumnRenamed('administration', 'administration_D')
                                                                 
              )
print('modified columns:', df_2.columns)

df_2.toPandas()
# Out:
# Actual columns: ['faa', 'name', 'lat', 'lon', 'alt', 'tz', 'dst', 'region', 'type', 'military', 'administration']
# modified columns: ['faa_D', 'name_D', 'lat_D', 'lon_D', 'alt_D', 'tz_D', 'dst_D', 'region_D', 'type_D', 'military_D', 'administration_D']
#      faa_D                         name_D      lat_D       lon_D  alt_D  tz_D  \
# 0      04G              Lansdowne Airport  41.130474  -80.619583   1044  -5.0
# 1      06A  Moton Field Municipal Airport  32.460571  -85.680031    264  -5.0
# 2      06C            Schaumburg Regional  41.989342  -88.101242    801  -6.0
# 3      06N                Randall Airport  41.431911  -74.391563    523  -5.0
# 4      09J          Jekyll Island Airport  31.074472  -81.427780     11  -4.0
# ...    ...                            ...        ...         ...    ...   ...
# 1392   ZUN                     Black Rock  35.083229 -108.791779   6454  -7.0
# 1393   ZVE         New Haven Rail Station  41.298668  -72.925995      7  -5.0
# 1394   ZWI      Wilmington Amtrak Station  39.736668  -75.551666      0  -5.0
# 1395   ZWU       Washington Union Station  38.897461  -77.006432     76  -5.0
# 1396   ZYP                   Penn Station  40.750500  -73.993500     35  -5.0
#
#      dst_D       region_D type_D  military_D administration_D
# 0        A  MAINLAND-EAST     AP       False              NaN
# 1        A  MAINLAND-EAST     AP       False                M
# 2        A  MAINLAND-EAST    NaN       False                R
# 3        A  MAINLAND-EAST     AP       False              NaN
# 4        A  MAINLAND-EAST     AP       False              NaN
# ...    ...            ...    ...         ...              ...
# 1392     A  MAINLAND-WEST    NaN       False              NaN
# 1393     A  MAINLAND-EAST     AS       False              NaN
# 1394     A  MAINLAND-EAST     AS       False              NaN
# 1395     A  MAINLAND-EAST     AS       False              NaN
# 1396     A  MAINLAND-EAST     AS       False              NaN
#
# [1397 rows x 11 columns]

# %%
print('Actual columns:', df_planes_proc.columns)


df_planes_proc = (df_planes_proc.withColumnRenamed('tailnum', 'tailnum_P')
                 )

print('modified columns:', df_planes_proc.columns)

df_planes_proc.toPandas()
# Out:
# Actual columns: ['tailnum', 'year', 'type', 'manufacturer', 'model', 'engines', 'seats', 'speed', 'engine', 'tailchar', 'age', 'engine_type']
# modified columns: ['tailnum_P', 'year', 'type', 'manufacturer', 'model', 'engines', 'seats', 'speed', 'engine', 'tailchar', 'age', 'engine_type']
#      tailnum_P    year       type manufacturer        model  engines  seats  \
# 0       N102UW  1998.0  MULTI_ENG       AIRBUS     A320-214        2    182
# 1       N103US  1999.0  MULTI_ENG       AIRBUS     A320-214        2    182
# 2       N104UW  1999.0  MULTI_ENG       AIRBUS     A320-214        2    182
# 3       N105UW  1999.0  MULTI_ENG       AIRBUS     A320-214        2    182
# 4       N107US  1999.0  MULTI_ENG       AIRBUS     A320-214        2    182
# ...        ...     ...        ...          ...          ...      ...    ...
# 2623    N983SW  2004.0  MULTI_ENG   BOMBARDIER  CL-600-2B19        2     55
# 2624    N984CA  1997.0  MULTI_ENG     CANADAIR  CL-600-2B19        2     55
# 2625    N986CA  1995.0  MULTI_ENG     CANADAIR  CL-600-2B19        2     55
# 2626    N986SW  2004.0  MULTI_ENG   BOMBARDIER  CL-600-2B19        2     55
# 2627    N988CA  1997.0  MULTI_ENG     CANADAIR  CL-600-2B19        2     55
#
#       speed     engine tailchar   age engine_type
# 0         0  Turbo-fan       UW  24.0         FAN
# 1         0  Turbo-fan       US  23.0         FAN
# 2         0  Turbo-fan       UW  23.0         FAN
# 3         0  Turbo-fan       UW  23.0         FAN
# 4         0  Turbo-fan       US  23.0         FAN
# ...     ...        ...      ...   ...         ...
# 2623      0  Turbo-fan       SW  18.0         FAN
# 2624      0  Turbo-fan       CA  25.0         FAN
# 2625      0  Turbo-fan       CA  27.0         FAN
# 2626      0  Turbo-fan       SW  18.0         FAN
# 2627      0  Turbo-fan       CA  25.0         FAN
#
# [2628 rows x 12 columns]

# %%
df = (df_flights_proc.join(df_1,
                  (df_flights_proc.origin == df_1.faa_O)
                        ,"left")
)

# %%
df.printSchema()
# Out:
# root
#  |-- dep_time: string (nullable = true)
#  |-- arr_time: string (nullable = true)
#  |-- dep_delay: integer (nullable = true)
#  |-- arr_delay: integer (nullable = true)
#  |-- carrier: string (nullable = true)
#  |-- tailnum: string (nullable = true)
#  |-- flight: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- dest: string (nullable = true)
#  |-- air_time: integer (nullable = true)
#  |-- distance: integer (nullable = true)
#  |-- dep_datetime: timestamp (nullable = true)
#  |-- air_time_projected: integer (nullable = true)
#  |-- air_time_expected: integer (nullable = true)
#  |-- haul_duration: string (nullable = true)
#  |-- dep_season: string (nullable = true)
#  |-- dep_delay_category: string (nullable = true)
#  |-- faa_O: string (nullable = true)
#  |-- name_O: string (nullable = true)
#  |-- lat_O: float (nullable = true)
#  |-- lon_O: float (nullable = true)
#  |-- alt_O: integer (nullable = true)
#  |-- tz_O: float (nullable = true)
#  |-- dst_O: string (nullable = true)
#  |-- region_O: string (nullable = true)
#  |-- type_O: string (nullable = true)
#  |-- military_O: boolean (nullable = true)
#  |-- administration_O: string (nullable = true)

# %%
df = (df.join(df_2,
                  (df.dest == df_2.faa_D)
                        ,"left")
)

# %%
df.printSchema()
# Out:
# root
#  |-- dep_time: string (nullable = true)
#  |-- arr_time: string (nullable = true)
#  |-- dep_delay: integer (nullable = true)
#  |-- arr_delay: integer (nullable = true)
#  |-- carrier: string (nullable = true)
#  |-- tailnum: string (nullable = true)
#  |-- flight: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- dest: string (nullable = true)
#  |-- air_time: integer (nullable = true)
#  |-- distance: integer (nullable = true)
#  |-- dep_datetime: timestamp (nullable = true)
#  |-- air_time_projected: integer (nullable = true)
#  |-- air_time_expected: integer (nullable = true)
#  |-- haul_duration: string (nullable = true)
#  |-- dep_season: string (nullable = true)
#  |-- dep_delay_category: string (nullable = true)
#  |-- faa_O: string (nullable = true)
#  |-- name_O: string (nullable = true)
#  |-- lat_O: float (nullable = true)
#  |-- lon_O: float (nullable = true)
#  |-- alt_O: integer (nullable = true)
#  |-- tz_O: float (nullable = true)
#  |-- dst_O: string (nullable = true)
#  |-- region_O: string (nullable = true)
#  |-- type_O: string (nullable = true)
#  |-- military_O: boolean (nullable = true)
#  |-- administration_O: string (nullable = true)
#  |-- faa_D: string (nullable = true)
#  |-- name_D: string (nullable = true)
#  |-- lat_D: float (nullable = true)
#  |-- lon_D: float (nullable = true)
#  |-- alt_D: integer (nullable = true)
#  |-- tz_D: float (nullable = true)
#  |-- dst_D: string (nullable = true)
#  |-- region_D: string (nullable = true)
#  |-- type_D: string (nullable = true)
#  |-- military_D: boolean (nullable = true)
#  |-- administration_D: string (nullable = true)

# %%
df = (df.join(df_planes_proc,
                  (df.tailnum == df_planes_proc.tailnum_P)
                        ,"left")
)

# %%
df.printSchema()
# Out:
# root
#  |-- dep_time: string (nullable = true)
#  |-- arr_time: string (nullable = true)
#  |-- dep_delay: integer (nullable = true)
#  |-- arr_delay: integer (nullable = true)
#  |-- carrier: string (nullable = true)
#  |-- tailnum: string (nullable = true)
#  |-- flight: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- dest: string (nullable = true)
#  |-- air_time: integer (nullable = true)
#  |-- distance: integer (nullable = true)
#  |-- dep_datetime: timestamp (nullable = true)
#  |-- air_time_projected: integer (nullable = true)
#  |-- air_time_expected: integer (nullable = true)
#  |-- haul_duration: string (nullable = true)
#  |-- dep_season: string (nullable = true)
#  |-- dep_delay_category: string (nullable = true)
#  |-- faa_O: string (nullable = true)
#  |-- name_O: string (nullable = true)
#  |-- lat_O: float (nullable = true)
#  |-- lon_O: float (nullable = true)
#  |-- alt_O: integer (nullable = true)
#  |-- tz_O: float (nullable = true)
#  |-- dst_O: string (nullable = true)
#  |-- region_O: string (nullable = true)
#  |-- type_O: string (nullable = true)
#  |-- military_O: boolean (nullable = true)
#  |-- administration_O: string (nullable = true)
#  |-- faa_D: string (nullable = true)
#  |-- name_D: string (nullable = true)
#  |-- lat_D: float (nullable = true)
#  |-- lon_D: float (nullable = true)
#  |-- alt_D: integer (nullable = true)
#  |-- tz_D: float (nullable = true)
#  |-- dst_D: string (nullable = true)
#  |-- region_D: string (nullable = true)
#  |-- type_D: string (nullable = true)
#  |-- military_D: boolean (nullable = true)
#  |-- administration_D: string (nullable = true)
#  |-- tailnum_P: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- type: string (nullable = true)
#  |-- manufacturer: string (nullable = true)
#  |-- model: string (nullable = true)
#  |-- engines: integer (nullable = true)
#  |-- seats: integer (nullable = true)
#  |-- speed: integer (nullable = true)
#  |-- engine: string (nullable = true)
#  |-- tailchar: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- engine_type: string (nullable = true)

# %%
len(df.columns)
# Out:
# 51

# %%
df.toPandas()
# Out:
#      dep_time arr_time  dep_delay  arr_delay carrier tailnum flight origin  \
# 0         658      935         -7         -5      VX  N846VA   1780    SEA
# 1        1040     1505          5          5      AS  N559AS    851    SEA
# 2        1443     1652         -2          2      VX  N847VA    755    SEA
# 3        1705     1839         45         34      WN  N360SW    344    PDX
# 4         754     1015         -1          1      AS  N612AS    522    SEA
# ...       ...      ...        ...        ...     ...     ...    ...    ...
# 9995     1806     2104         -4         -6      OO  N225AG   3458    SEA
# 9996     2336      452         11        -13      AA  N3LEAA   1230    SEA
# 9997      904     1042         -1         -5      AS  N523AS    360    SEA
# 9998     1441     1820         26         10      WN  N8647A   2857    SEA
# 9999     1702     1950         -3        -10      DL  N583NW   2237    SEA
#
#      dest  air_time  ...       type manufacturer        model  engines  seats  \
# 0     LAX       132  ...  MULTI_ENG       AIRBUS     A320-214      2.0  182.0
# 1     HNL       360  ...  MULTI_ENG       BOEING      737-890      2.0  149.0
# 2     SFO       111  ...  MULTI_ENG       AIRBUS     A320-214      2.0  182.0
# 3     SJC        83  ...  MULTI_ENG       BOEING      737-3H4      2.0  149.0
# 4     BUR       127  ...  MULTI_ENG       BOEING      737-790      2.0  151.0
# ...   ...       ...  ...        ...          ...          ...      ...    ...
# 9995  SLC        89  ...  MULTI_ENG   BOMBARDIER  CL-600-2C10      2.0   80.0
# 9996  DFW       178  ...       None         None         None      NaN    NaN
# 9997  SMF        81  ...  MULTI_ENG       BOEING      737-890      2.0  149.0
# 9998  ABQ       133  ...  MULTI_ENG       BOEING      737-8H4      2.0  140.0
# 9999  HNL       332  ...  MULTI_ENG       BOEING      757-351      2.0  275.0
#
#      speed     engine tailchar   age  engine_type
# 0      0.0  Turbo-fan       VA  11.0          FAN
# 1      0.0  Turbo-fan       AS  16.0          FAN
# 2      0.0  Turbo-fan       VA  11.0          FAN
# 3      0.0  Turbo-fan       SW  30.0          FAN
# 4      0.0  Turbo-jet       AS  23.0          JET
# ...    ...        ...      ...   ...          ...
# 9995   0.0  Turbo-fan       AG  21.0          FAN
# 9996   NaN       None     None   NaN         None
# 9997   0.0  Turbo-fan       AS  13.0          FAN
# 9998   0.0  Turbo-fan        A   8.0          FAN
# 9999   0.0  Turbo-jet       NW  20.0          JET
#
# [10000 rows x 51 columns]

# %%
# df.write.csv(
#         path = "C:/Users/danielpe/reports/csv", 
#         mode= "overwrite", 
#         sep=";", 
#         header=True)

# %% [markdown]
# #### Pergunta 2

# %%
df.groupBy(F.col('region_D')).agg(F.countDistinct('faa_D').alias('aeroportos_por_regiao')).toPandas()
# Out:
#         region_D  aeroportos_por_regiao
# 0         ALASKA                      9
# 1  MAINLAND-EAST                     24
# 2  MAINLAND-WEST                     36

# %% [markdown]
# #### Pergunta 3

# %%
(df.agg(F.max(F.col("alt_O") - F.col("alt_D")).alias("maior_dif_altitude")).toPandas()
)
# Out:
#    maior_dif_altitude
# 0                 429

# %% [markdown]
# #### Pergunta 4

# %%
(df.select("dep_delay", "arr_delay")
            .where('dep_delay > 0 OR arr_delay > 0')
            .agg(F.ceil(F.avg(F.col('dep_delay') + F.col('arr_delay'))).alias("atraso_medio")).toPandas()
)
# Out:
#    atraso_medio
# 0            35

# %% [markdown]
# #### Pergunta 5

# %%
(df.where('dep_delay > 0 OR arr_delay > 0')
   .groupBy("region_D" )
   .agg(F.ceil(F.avg(F.col('dep_delay') + F.col('arr_delay'))).alias("atraso_medio_regiao (min)")).toPandas()
)
# Out:
#         region_D  atraso_medio_regiao (min)
# 0         ALASKA                         28
# 1  MAINLAND-EAST                         37
# 2  MAINLAND-WEST                         36

# %% [markdown]
# #### Pergunta 6

# %%
(df.where((F.col('dep_delay') > 0) | (F.col('arr_delay') > 0))
   .groupBy(F.year(F.col('dep_datetime')).alias('ano'))
   .agg(F.sum(F.col('dep_delay') + F.col('arr_delay')).alias('atraso_acumulado_ano (min)'))
   .toPandas()
)
# Out:
#     ano  atraso_acumulado_ano (min)
# 0  2014                      166798

# %% [markdown]
# #### Pergunta 7

# %%
(df.select(F.year("dep_datetime").alias('ano'),"dep_delay",'arr_delay',"region_D")
   .where('dep_delay > 0 OR arr_delay > 0')
   .groupBy("ano", "region_D")
   .agg(F.sum(F.col('dep_delay') + F.col('arr_delay')).alias('atraso_acumulado_ano (min)'))
   .toPandas()
)
# Out:
#     ano       region_D  atraso_acumulado_ano (min)
# 0  2014         ALASKA                       14281
# 1  2014  MAINLAND-EAST                       40558
# 2  2014  MAINLAND-WEST                      111959

# %% [markdown]
# #### Pergunta 8

# %%
(df.select("air_time")   
   .agg(F.ceil(F.avg("air_time")).alias("tempo_voo_medio")).toPandas()
)
# Out:
#    tempo_voo_medio
# 0              153

# %% [markdown]
# #### Pergunta 9

# %%
(df.select("air_time", "region_D")
   .groupBy("region_D")
   .agg(F.ceil(F.avg("air_time")).alias("tempo_voo_medio_regiao")).toPandas()
)
# Out:
#         region_D  tempo_voo_medio_regiao
# 0         ALASKA                     228
# 1  MAINLAND-EAST                     238
# 2  MAINLAND-WEST                     116

# %% [markdown]
# #### Pergunta 10

# %%
(df.select("air_time", "origin","dest")
   .groupBy("origin", "dest")
   .agg(F.ceil(F.avg("air_time")).alias("tempo_voo_medio_rota")).toPandas()
)
# Out:
#     origin dest  tempo_voo_medio_rota
# 0      SEA  RNO                    75
# 1      SEA  DTW                   220
# 2      SEA  CLE                   234
# 3      SEA  LAX                   127
# 4      PDX  SEA                    35
# ..     ...  ...                   ...
# 108    SEA  JFK                   282
# 109    SEA  FAI                   199
# 110    PDX  HOU                   227
# 111    PDX  BUR                   109
# 112    SEA  MCO                   299
#
# [113 rows x 3 columns]

# %% [markdown]
# #### Pergunta 11

# %%
(df.select(F.year("dep_datetime").alias('ano'),"air_time")
   .groupBy("ano")
   .agg(F.sum('air_time').alias('tempo_voo_acumulado_ano'))
   .toPandas()
)
# Out:
#     ano  tempo_voo_acumulado_ano
# 0  2014                  1528625

# %% [markdown]
# #### Pergunta 12

# %%
(df.select(F.year("dep_datetime").alias('ano'),"air_time","region_D")
   .groupBy("ano", "region_D")
   .agg(F.sum(F.col('air_time')).alias('tempo_voo_acumulado_regiao'))
   .toPandas()
)
# Out:
#     ano       region_D  tempo_voo_acumulado_regiao
# 0  2014         ALASKA                      230602
# 1  2014  MAINLAND-EAST                      508344
# 2  2014  MAINLAND-WEST                      789679

# %% [markdown]
# #### Pergunta 13

# %%
(df.select("distance")
   .agg(F.ceil(F.avg(F.col('distance'))).alias('distancia_voo_medio_regiao'))
   .toPandas()
)
# Out:
#    distancia_voo_medio_regiao
# 0                        1209

# %% [markdown]
# #### Pergunta 14

# %%
(df.select("distance", "region_D")
   .groupBy("region_D")
   .agg(F.ceil(F.avg(F.col('distance'))).alias('distancia_voo_medio_regiao'))
   .toPandas()
)
# Out:
#         region_D  distancia_voo_medio_regiao
# 0         ALASKA                        1742
# 1  MAINLAND-EAST                        2043
# 2  MAINLAND-WEST                         868

# %% [markdown]
# #### Pergunta 15

# %%
(df.select("distance", "origin","dest")
   .groupBy("origin", "dest")
   .agg(F.ceil(F.avg("distance")).alias("distancia_voo_medio_rota")).toPandas()
)
# Out:
#     origin dest  distancia_voo_medio_rota
# 0      SEA  RNO                       564
# 1      SEA  DTW                      1927
# 2      SEA  CLE                      2021
# 3      SEA  LAX                       954
# 4      PDX  SEA                       129
# ..     ...  ...                       ...
# 108    SEA  JFK                      2422
# 109    SEA  FAI                      1533
# 110    PDX  HOU                      1843
# 111    PDX  BUR                       817
# 112    SEA  MCO                      2554
#
# [113 rows x 3 columns]

# %% [markdown]
# #### Pergunta 16

# %%
(df.select(F.year("dep_datetime").alias('ano'),"distance")
   .groupBy("ano")
   .agg(F.ceil(F.sum('distance')).alias('distancia_voo_acumulado_ano'))
   .toPandas()
)
# Out:
#     ano  distancia_voo_acumulado_ano
# 0  2014                     12081516

# %% [markdown]
# #### Pergunta 17

# %%
(df.select(F.year("dep_datetime").alias('ano'),"distance","region_D")
   .groupBy("ano", "region_D")
   .agg(F.ceil(F.sum(F.col('distance'))).alias('distancia_acumulado_regiao'))
   .toPandas()
)
# Out:
#     ano       region_D  distancia_acumulado_regiao
# 0  2014         ALASKA                     1762553
# 1  2014  MAINLAND-EAST                     4378902
# 2  2014  MAINLAND-WEST                     5940061

# %% [markdown]
# #### Pergunta 18

# %%
(df.select("seats", "origin","dest")
   .groupBy("origin", "dest")
   .agg(F.round(F.avg("seats"), 3).alias("passageiros_medio_rota")).toPandas()
)
# Out:
#     origin dest  passageiros_medio_rota
# 0      SEA  RNO                 141.125
# 1      SEA  DTW                 212.429
# 2      SEA  CLE                 182.000
# 3      SEA  LAX                 154.711
# 4      PDX  SEA                  64.282
# ..     ...  ...                     ...
# 108    SEA  JFK                 182.600
# 109    SEA  FAI                 179.903
# 110    PDX  HOU                 141.500
# 111    PDX  BUR                  79.648
# 112    SEA  MCO                 165.484
#
# [113 rows x 3 columns]

# %% [markdown]
# #### Pergunta 19

# %%
(df.select(F.year("dep_datetime").alias("ano"),"seats")
   .groupBy("ano",)
   .agg(F.sum("seats").alias("passageiros_acumulado_ano")).toPandas()
)
# Out:
#     ano  passageiros_acumulado_ano
# 0  2014                    1509544

# %% [markdown]
# #### Pergunta 20

# %%
(df.select("dest")
   .groupBy("dest")
   .count()
   .orderBy('count', ascending= False)
   .limit(1)
   .toPandas()
)
# Out:
#   dest  count
# 0  SFO    787

# %% [markdown]
# #### Pergunta 21

# %%
(df.select("dest", "seats")
   .groupBy("dest")
   .agg(F.sum("seats").alias("destino_mais_passageiros"))
   .orderBy("destino_mais_passageiros", ascending= False)
   .limit(1)
   .toPandas()
)
# Out:
#   dest  destino_mais_passageiros
# 0  SFO                    119635

# %% [markdown]
# #### Pergunta 22

# %%
(df.select( "origin","dest", "distance")
   .where(F.col("origin") == "PDX")   
   .orderBy("distance", ascending = False)
   .limit(1)
   .toPandas()

)
# Out:
#   origin dest  distance
# 0    PDX  LIH      2631

# %% [markdown]
# #### Pergunta 23

# %%
(df.groupBy("dest", F.month("dep_datetime").alias('mes'))
   .count()
   .orderBy('count', ascending= False)
   .limit(1)
   .toPandas()
)
# Out:
#   dest  mes  count
# 0  LAX    5     77

# %% [markdown]
# #### Pergunta 24

# %%
(df.groupBy("model")
   .count()
   .orderBy('count', ascending= False)
   .limit(1)
   .toPandas()
)
# Out:
#      model  count
# 0  737-890   1463

# %% [markdown]
# #### Pergunta 25

# %%
(df.where(F.col("model").isNotNull()) 
   .groupBy("model", "dest")
   .count()
   .orderBy('count', ascending= False)
   .limit(1)
   .toPandas()
)
# Out:
#      model dest  count
# 0  737-7H4  OAK    141

# %% [markdown]
# #### Pergunta 26

# %%
(df.groupBy("haul_duration")
   .agg(F.avg("engines").alias("media_motores_categoria"))
   .toPandas())
# Out:
#   haul_duration  media_motores_categoria
# 0     LONG-HAUL                 2.000000
# 1   MEDIUM-HAUL                 1.999643
# 2    SHORT-HAUL                 1.999242

# %% [markdown]
# #### Pergunta 27

# %%
(df.groupBy("dep_season")
   .count()
   .orderBy('count', ascending= False)
   .limit(1)
   .toPandas()
)
# Out:
#   dep_season  count
# 0     SUMMER   2918

# %% [markdown]
# #### Pergunta 28

# %%
(df.groupBy("dep_season", "dest")
   .count()
   .orderBy('count', ascending= False)
   .limit(1)
   .toPandas()
)
# Out:
#   dep_season dest  count
# 0     SUMMER  SFO    217

# %% [markdown]
# #### Pergunta 29

# %%
(df.where((F.col('dep_delay_category') != 'ANTECIPATED') & (F.col('dep_delay_category') != 'INTIME'))
   .groupBy("dep_delay_category")
   .count()
   .orderBy('count', ascending= False)
   .limit(1)
   .toPandas()
)
# Out:
#   dep_delay_category  count
# 0              MINOR   3065

# %% [markdown]
# #### Pergunta 30

# %%
(df.where((F.col('dep_delay_category') != 'ANTECIPATED') & (F.col('dep_delay_category') != 'INTIME'))
   .groupBy("dep_delay_category", "origin","dest")
   .count()
   .orderBy('count', ascending= False)
   .limit(1)
   .toPandas()
)
# Out:
#   dep_delay_category origin dest  count
# 0              MINOR    SEA  SFO    159
